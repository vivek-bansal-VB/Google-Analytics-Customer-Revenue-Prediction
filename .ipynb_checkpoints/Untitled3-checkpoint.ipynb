# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error
import gc
import time
from pandas.core.common import SettingWithCopyWarning
import warnings
import lightgbm as lgb
from sklearn.model_selection import GroupKFold

# I don't like SettingWithCopyWarnings ...
warnings.simplefilter('error', SettingWithCopyWarning)
gc.enable()
# %matplotlib inline
from sklearn import preprocessing

# %%
def load_df(csv_path='train.csv', nrows=None):
    JSON_COLUMNS = ['device', 'geoNetwork', 'totals', 'trafficSource']
    
    df = pd.read_csv(csv_path, 
                     converters={column: json.loads for column in JSON_COLUMNS}, 
                     dtype={'date': 'str', 'fullVisitorId': 'str', 'sessionId':'str'}, # Important!!
                     nrows=nrows)
    
    for column in JSON_COLUMNS:
        column_as_df = json_normalize(df[column])
        column_as_df.columns = [f"{column}.{subcolumn}" for subcolumn in column_as_df.columns]
        df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
    print(f"Loaded {os.path.basename(csv_path)}. Shape: {df.shape}")
    return df

# %%
train = load_df('train.csv')
test = load_df("test.csv")
# Out:
# Loaded train.csv. Shape: (903653, 55)
# Loaded test.csv. Shape: (804684, 53)

# %%
def get_folds(df=None, n_splits=5):
    """Returns dataframe indices corresponding to Visitors Group KFold"""
    # Get sorted unique visitors
    unique_vis = np.array(sorted(df['fullVisitorId'].unique()))

    # Get folds
    folds = GroupKFold(n_splits=n_splits)
    fold_ids = []
    ids = np.arange(df.shape[0])
    for trn_vis, val_vis in folds.split(X=unique_vis, y=unique_vis, groups=unique_vis):
        fold_ids.append(
            [
                ids[df['fullVisitorId'].isin(unique_vis[trn_vis])],
                ids[df['fullVisitorId'].isin(unique_vis[val_vis])]
            ]
        )

    return fold_ids

# %%
y_reg = train['totals.transactionRevenue'].fillna(0)
del train['totals.transactionRevenue']

if 'totals.transactionRevenue' in test.columns:
    del test['totals.transactionRevenue']

# %%
cat_cols = ["channelGrouping", "device.browser", 
            "device.deviceCategory", "device.operatingSystem", 
            "geoNetwork.city", "geoNetwork.continent", 
            "geoNetwork.country", "geoNetwork.metro",
            "geoNetwork.networkDomain", "geoNetwork.region", 
            "geoNetwork.subContinent", "trafficSource.adContent", 
            "trafficSource.adwordsClickInfo.adNetworkType", 
            "trafficSource.adwordsClickInfo.gclId", 
            "trafficSource.adwordsClickInfo.page", 
            "trafficSource.adwordsClickInfo.slot", "trafficSource.campaign",
            "trafficSource.keyword", "trafficSource.medium", 
            "trafficSource.referralPath", "trafficSource.source",
            'trafficSource.adwordsClickInfo.isVideoAd', 'trafficSource.isTrueDirect',
            'trafficSource.campaignCode']
for col in cat_cols:
    print(col)
    lbl = preprocessing.LabelEncoder()
    lbl.fit(list(train[col].values.astype('str')) + list(test[col].values.astype('str')))
    train[col] = lbl.transform(list(train[col].values.astype('str')))
    test[col] = lbl.transform(list(test[col].values.astype('str')))


num_cols = ["totals.hits", "totals.pageviews", "visitNumber", "visitStartTime", 'totals.bounces',  'totals.newVisits']    
for col in num_cols:
    train[col] = train[col].astype(float)
    test[col] = test[col].astype(float)
# Out:
# channelGrouping
# device.browser
# device.deviceCategory
# device.operatingSystem
# geoNetwork.city
# geoNetwork.continent
# geoNetwork.country
# geoNetwork.metro
# geoNetwork.networkDomain
# geoNetwork.region
# geoNetwork.subContinent
# trafficSource.adContent
# trafficSource.adwordsClickInfo.adNetworkType
# trafficSource.adwordsClickInfo.gclId
# trafficSource.adwordsClickInfo.page
# trafficSource.adwordsClickInfo.slot
# trafficSource.campaign
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'trafficSource.campaign'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-c36faf8b703e> in <module>()
#      16     print(col)
#      17     lbl = preprocessing.LabelEncoder()
# ---> 18     lbl.fit(list(train[col].values.astype('str')) + list(test[col].values.astype('str')))
#      19     train[col] = lbl.transform(list(train[col].values.astype('str')))
#      20     test[col] = lbl.transform(list(test[col].values.astype('str')))
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'trafficSource.campaign'

# %%
train['target'] = y_reg
for df in [train, test]:
    df['vis_date'] = pd.to_datetime(df['visitStartTime'], unit='s')
    df['sess_date_dow'] = df['vis_date'].dt.dayofweek
    df['sess_date_hours'] = df['vis_date'].dt.hour
    df['sess_date_dom'] = df['vis_date'].dt.day
    df.sort_values(['fullVisitorId', 'vis_date'], ascending=True, inplace=True)
    df['next_session_1'] = (
        df['vis_date'] - df[['fullVisitorId', 'vis_date']].groupby('fullVisitorId')['vis_date'].shift(1)
    ).astype(np.int64) // 1e9 // 60 // 60
    df['next_session_2'] = (
        df['vis_date'] - df[['fullVisitorId', 'vis_date']].groupby('fullVisitorId')['vis_date'].shift(-1)
    ).astype(np.int64) // 1e9 // 60 // 60
    
#     df['max_visits'] = df['fullVisitorId'].map(
#         df[['fullVisitorId', 'visitNumber']].groupby('fullVisitorId')['visitNumber'].max()
#     )
    
    df['nb_pageviews'] = df['date'].map(
        df[['date', 'totals.pageviews']].groupby('date')['totals.pageviews'].sum()
    )
    
    df['ratio_pageviews'] = df['totals.pageviews'] / df['nb_pageviews']
    
#     df['nb_sessions'] = df['date'].map(
#         df[['date']].groupby('date').size()
#     )
    
#     df['nb_sessions_28_ma'] = df['date'].map(
#         df[['date']].groupby('date').size().rolling(28, min_periods=7).mean()
#     )

#     df['nb_sessions_28_ma'] = df['nb_sessions'] / df['nb_sessions_28_ma']

#     df['nb_sessions_per_day'] = df['date'].map(
#         df[['date']].groupby('date').size()
#     )
    
#     df['nb_visitors_per_day'] = df['date'].map(
#         df[['date','fullVisitorId']].groupby('date')['fullVisitorId'].nunique()
#     )

y_reg = train['target']
del train['target']
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in f(self, **kwargs)
#    1421                     return self._cython_agg_general(
# -> 1422                         alias, alt=npfunc, **kwargs)
#    1423                 except AssertionError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1055         if len(output) == 0:
# -> 1056             raise DataError('No numeric types to aggregate')
#    1057
#
# DataError: No numeric types to aggregate
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in aggregate(self, func_or_funcs, *args, **kwargs)
#    3494             try:
# -> 3495                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#    3496             except Exception:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _python_agg_general(self, func, *args, **kwargs)
#    1073         if len(output) == 0:
# -> 1074             return self._python_apply_general(f)
#    1075
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    1061         func = self._is_builtin_func(func)
# -> 1062         f = lambda x: func(x, *args, **kwargs)
#    1063
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    1426                     result = self.aggregate(
# -> 1427                         lambda x: npfunc(x, axis=self.axis))
#    1428                     if _convert:
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial)
#    1929     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# -> 1930                           initial=initial)
#    1931
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      80             else:
# ---> 81                 return reduction(axis=axis, out=out, **passkwargs)
#      82
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#    9568         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 9569                             numeric_only=numeric_only, min_count=min_count)
#    9570
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3217             with np.errstate(all='ignore'):
# -> 3218                 return op(delegate, skipna=skipna, **kwds)
#    3219
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      76                 with np.errstate(invalid='ignore'):
# ---> 77                     return f(*args, **kwargs)
#      78             except ValueError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in nansum(values, axis, skipna, min_count)
#     335         dtype_sum = np.float64
# --> 336     the_sum = values.sum(axis, dtype=dtype_sum)
#     337     the_sum = _maybe_null_out(the_sum, axis, mask, min_count=min_count)
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial)
#      35          initial=_NoValue):
# ---> 36     return umr_sum(a, axis, dtype, out, keepdims, initial)
#      37
#
# TypeError: must be str, not int
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-42023e64bfd7> in <module>()
#      18
#      19     df['nb_pageviews'] = df['date'].map(
# ---> 20         df[['date', 'totals.pageviews']].groupby('date')['totals.pageviews'].sum()
#      21     )
#      22
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in f(self, **kwargs)
#    1425                 except Exception:
#    1426                     result = self.aggregate(
# -> 1427                         lambda x: npfunc(x, axis=self.axis))
#    1428                     if _convert:
#    1429                         result = result._convert(datetime=True)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in aggregate(self, func_or_funcs, *args, **kwargs)
#    3495                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#    3496             except Exception:
# -> 3497                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#    3498
#    3499             index = Index(sorted(result), name=self.grouper.names[0])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _aggregate_named(self, func, *args, **kwargs)
#    3625         for name, group in self:
#    3626             group.name = name
# -> 3627             output = func(group, *args, **kwargs)
#    3628             if isinstance(output, (Series, Index, np.ndarray)):
#    3629                 raise Exception('Must produce aggregated value')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    1425                 except Exception:
#    1426                     result = self.aggregate(
# -> 1427                         lambda x: npfunc(x, axis=self.axis))
#    1428                     if _convert:
#    1429                         result = result._convert(datetime=True)
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial)
#    1928
#    1929     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# -> 1930                           initial=initial)
#    1931
#    1932
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      79                 return reduction(axis=axis, dtype=dtype, out=out, **passkwargs)
#      80             else:
# ---> 81                 return reduction(axis=axis, out=out, **passkwargs)
#      82
#      83     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#    9567                                       skipna=skipna, min_count=min_count)
#    9568         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 9569                             numeric_only=numeric_only, min_count=min_count)
#    9570
#    9571     return set_function_name(stat_func, name, cls)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3216                                           'numeric_only.'.format(name))
#    3217             with np.errstate(all='ignore'):
# -> 3218                 return op(delegate, skipna=skipna, **kwds)
#    3219
#    3220         return delegate._reduce(op=op, name=name, axis=axis, skipna=skipna,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      75             try:
#      76                 with np.errstate(invalid='ignore'):
# ---> 77                     return f(*args, **kwargs)
#      78             except ValueError as e:
#      79                 # we want to transform an object array
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in nansum(values, axis, skipna, min_count)
#     334     elif is_timedelta64_dtype(dtype):
#     335         dtype_sum = np.float64
# --> 336     the_sum = values.sum(axis, dtype=dtype_sum)
#     337     the_sum = _maybe_null_out(the_sum, axis, mask, min_count=min_count)
#     338
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial)
#      34 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      35          initial=_NoValue):
# ---> 36     return umr_sum(a, axis, dtype, out, keepdims, initial)
#      37
#      38 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: must be str, not int

# %%
excluded_features = [
    'date', 'fullVisitorId', 'sessionId', 'totals.transactionRevenue', 
    'visitId', 'visitStartTime', 'vis_date', 'nb_sessions', 'max_visits'
]

categorical_features = [
    _f for _f in train.columns
    if (_f not in excluded_features) & (train[_f].dtype == 'object')
]
train.corr()
# Out:
#                                                    channelGrouping  \
# channelGrouping                                           1.000000
# socialEngagementType                                           NaN
# visitId                                                  -0.206452
# visitNumber                                              -0.039646
# visitStartTime                                           -0.206453
# device.browser                                           -0.080803
# device.browserSize                                             NaN
# device.browserVersion                                          NaN
# device.deviceCategory                                    -0.219050
# device.flashVersion                                            NaN
# device.isMobile                                          -0.238215
# device.language                                                NaN
# device.mobileDeviceBranding                                    NaN
# device.mobileDeviceInfo                                        NaN
# device.mobileDeviceMarketingName                               NaN
# device.mobileDeviceModel                                       NaN
# device.mobileInputSelector                                     NaN
# device.operatingSystem                                    0.184429
# device.operatingSystemVersion                                  NaN
# device.screenColors                                            NaN
# device.screenResolution                                        NaN
# geoNetwork.city                                           0.063901
# geoNetwork.cityId                                              NaN
# geoNetwork.continent                                      0.024573
# geoNetwork.country                                        0.168907
# geoNetwork.latitude                                            NaN
# geoNetwork.longitude                                           NaN
# geoNetwork.metro                                         -0.015681
# geoNetwork.networkDomain                                  0.083608
# geoNetwork.networkLocation                                     NaN
# geoNetwork.region                                         0.018244
# geoNetwork.subContinent                                   0.020709
# totals.bounces                                                 NaN
# totals.hits                                              -0.063704
# totals.newVisits                                               NaN
# totals.pageviews                                         -0.066702
# totals.visits                                                  NaN
# trafficSource.adContent                                  -0.018922
# trafficSource.adwordsClickInfo.adNetworkType             -0.034681
# trafficSource.adwordsClickInfo.criteriaParameters              NaN
# trafficSource.adwordsClickInfo.gclId                     -0.030574
# trafficSource.adwordsClickInfo.isVideoAd                 -0.034683
# trafficSource.adwordsClickInfo.page                      -0.034674
# trafficSource.adwordsClickInfo.slot                      -0.034379
# trafficSource.isTrueDirect                                0.459128
# trafficSource.keyword                                     0.226229
# trafficSource.medium                                      0.820530
# trafficSource.referralPath                                0.050845
# trafficSource.source                                      0.292056
# sess_date_dow                                             0.030038
# sess_date_hours                                          -0.028144
# sess_date_dom                                             0.007991
# next_session_1                                           -0.067592
# next_session_2                                           -0.102199
# nb_pageviews                                              0.124799
# ratio_pageviews                                          -0.072485
#
#                                                    socialEngagementType  \
# channelGrouping                                                     NaN
# socialEngagementType                                                NaN
# visitId                                                             NaN
# visitNumber                                                         NaN
# visitStartTime                                                      NaN
# device.browser                                                      NaN
# device.browserSize                                                  NaN
# device.browserVersion                                               NaN
# device.deviceCategory                                               NaN
# device.flashVersion                                                 NaN
# device.isMobile                                                     NaN
# device.language                                                     NaN
# device.mobileDeviceBranding                                         NaN
# device.mobileDeviceInfo                                             NaN
# device.mobileDeviceMarketingName                                    NaN
# device.mobileDeviceModel                                            NaN
# device.mobileInputSelector                                          NaN
# device.operatingSystem                                              NaN
# device.operatingSystemVersion                                       NaN
# device.screenColors                                                 NaN
# device.screenResolution                                             NaN
# geoNetwork.city                                                     NaN
# geoNetwork.cityId                                                   NaN
# geoNetwork.continent                                                NaN
# geoNetwork.country                                                  NaN
# geoNetwork.latitude                                                 NaN
# geoNetwork.longitude                                                NaN
# geoNetwork.metro                                                    NaN
# geoNetwork.networkDomain                                            NaN
# geoNetwork.networkLocation                                          NaN
# geoNetwork.region                                                   NaN
# geoNetwork.subContinent                                             NaN
# totals.bounces                                                      NaN
# totals.hits                                                         NaN
# totals.newVisits                                                    NaN
# totals.pageviews                                                    NaN
# totals.visits                                                       NaN
# trafficSource.adContent                                             NaN
# trafficSource.adwordsClickInfo.adNetworkType                        NaN
# trafficSource.adwordsClickInfo.criteriaParameters                   NaN
# trafficSource.adwordsClickInfo.gclId                                NaN
# trafficSource.adwordsClickInfo.isVideoAd                            NaN
# trafficSource.adwordsClickInfo.page                                 NaN
# trafficSource.adwordsClickInfo.slot                                 NaN
# trafficSource.isTrueDirect                                          NaN
# trafficSource.keyword                                               NaN
# trafficSource.medium                                                NaN
# trafficSource.referralPath                                          NaN
# trafficSource.source                                                NaN
# sess_date_dow                                                       NaN
# sess_date_hours                                                     NaN
# sess_date_dom                                                       NaN
# next_session_1                                                      NaN
# next_session_2                                                      NaN
# nb_pageviews                                                        NaN
# ratio_pageviews                                                     NaN
#
#                                                     visitId  visitNumber  \
# channelGrouping                                   -0.206452    -0.039646
# socialEngagementType                                    NaN          NaN
# visitId                                            1.000000     0.004475
# visitNumber                                        0.004475     1.000000
# visitStartTime                                     1.000000     0.004475
# device.browser                                     0.043879     0.050322
# device.browserSize                                      NaN          NaN
# device.browserVersion                                   NaN          NaN
# device.deviceCategory                              0.139118    -0.038334
# device.flashVersion                                     NaN          NaN
# device.isMobile                                    0.151480    -0.040382
# device.language                                         NaN          NaN
# device.mobileDeviceBranding                             NaN          NaN
# device.mobileDeviceInfo                                 NaN          NaN
# device.mobileDeviceMarketingName                        NaN          NaN
# device.mobileDeviceModel                                NaN          NaN
# device.mobileInputSelector                              NaN          NaN
# device.operatingSystem                            -0.114146     0.026883
# device.operatingSystemVersion                           NaN          NaN
# device.screenColors                                     NaN          NaN
# device.screenResolution                                 NaN          NaN
# geoNetwork.city                                   -0.001128    -0.020661
# geoNetwork.cityId                                       NaN          NaN
# geoNetwork.continent                              -0.003126    -0.065560
# geoNetwork.country                                -0.080651    -0.071014
# geoNetwork.latitude                                     NaN          NaN
# geoNetwork.longitude                                    NaN          NaN
# geoNetwork.metro                                   0.059224     0.018333
# geoNetwork.networkDomain                          -0.062793    -0.037341
# geoNetwork.networkLocation                              NaN          NaN
# geoNetwork.region                                  0.024350    -0.003106
# geoNetwork.subContinent                           -0.028553     0.046953
# totals.bounces                                          NaN          NaN
# totals.hits                                       -0.031347     0.039546
# totals.newVisits                                        NaN          NaN
# totals.pageviews                                  -0.025055     0.043521
# totals.visits                                           NaN          NaN
# trafficSource.adContent                           -0.108826     0.015310
# trafficSource.adwordsClickInfo.adNetworkType      -0.047342     0.002456
# trafficSource.adwordsClickInfo.criteriaParameters       NaN          NaN
# trafficSource.adwordsClickInfo.gclId              -0.027509     0.002062
# trafficSource.adwordsClickInfo.isVideoAd          -0.047321     0.002460
# trafficSource.adwordsClickInfo.page               -0.047407     0.002445
# trafficSource.adwordsClickInfo.slot               -0.047086     0.002600
# trafficSource.isTrueDirect                        -0.043364    -0.183824
# trafficSource.keyword                             -0.157927    -0.010122
# trafficSource.medium                              -0.090602    -0.035906
# trafficSource.referralPath                        -0.050508    -0.015744
# trafficSource.source                               0.051477    -0.032846
# sess_date_dow                                     -0.034480    -0.018210
# sess_date_hours                                    0.001908     0.026477
# sess_date_dom                                     -0.057315    -0.001386
# next_session_1                                     0.030948     0.273839
# next_session_2                                     0.004611     0.204823
# nb_pageviews                                      -0.585317     0.009575
# ratio_pageviews                                    0.070042     0.037563
#
#                                                    visitStartTime  \
# channelGrouping                                         -0.206453
# socialEngagementType                                          NaN
# visitId                                                  1.000000
# visitNumber                                              0.004475
# visitStartTime                                           1.000000
# device.browser                                           0.043879
# device.browserSize                                            NaN
# device.browserVersion                                         NaN
# device.deviceCategory                                    0.139118
# device.flashVersion                                           NaN
# device.isMobile                                          0.151480
# device.language                                               NaN
# device.mobileDeviceBranding                                   NaN
# device.mobileDeviceInfo                                       NaN
# device.mobileDeviceMarketingName                              NaN
# device.mobileDeviceModel                                      NaN
# device.mobileInputSelector                                    NaN
# device.operatingSystem                                  -0.114146
# device.operatingSystemVersion                                 NaN
# device.screenColors                                           NaN
# device.screenResolution                                       NaN
# geoNetwork.city                                         -0.001128
# geoNetwork.cityId                                             NaN
# geoNetwork.continent                                    -0.003126
# geoNetwork.country                                      -0.080651
# geoNetwork.latitude                                           NaN
# geoNetwork.longitude                                          NaN
# geoNetwork.metro                                         0.059224
# geoNetwork.networkDomain                                -0.062793
# geoNetwork.networkLocation                                    NaN
# geoNetwork.region                                        0.024350
# geoNetwork.subContinent                                 -0.028553
# totals.bounces                                                NaN
# totals.hits                                             -0.031346
# totals.newVisits                                              NaN
# totals.pageviews                                        -0.025055
# totals.visits                                                 NaN
# trafficSource.adContent                                 -0.108826
# trafficSource.adwordsClickInfo.adNetworkType            -0.047342
# trafficSource.adwordsClickInfo.criteriaParameters             NaN
# trafficSource.adwordsClickInfo.gclId                    -0.027509
# trafficSource.adwordsClickInfo.isVideoAd                -0.047321
# trafficSource.adwordsClickInfo.page                     -0.047407
# trafficSource.adwordsClickInfo.slot                     -0.047086
# trafficSource.isTrueDirect                              -0.043364
# trafficSource.keyword                                   -0.157927
# trafficSource.medium                                    -0.090603
# trafficSource.referralPath                              -0.050508
# trafficSource.source                                     0.051477
# sess_date_dow                                           -0.034480
# sess_date_hours                                          0.001907
# sess_date_dom                                           -0.057315
# next_session_1                                           0.030948
# next_session_2                                           0.004611
# nb_pageviews                                            -0.585317
# ratio_pageviews                                          0.070042
#
#                                                    device.browser  \
# channelGrouping                                         -0.080803
# socialEngagementType                                          NaN
# visitId                                                  0.043879
# visitNumber                                              0.050322
# visitStartTime                                           0.043879
# device.browser                                           1.000000
# device.browserSize                                            NaN
# device.browserVersion                                         NaN
# device.deviceCategory                                   -0.227155
# device.flashVersion                                           NaN
# device.isMobile                                         -0.216460
# device.language                                               NaN
# device.mobileDeviceBranding                                   NaN
# device.mobileDeviceInfo                                       NaN
# device.mobileDeviceMarketingName                              NaN
# device.mobileDeviceModel                                      NaN
# device.mobileInputSelector                                    NaN
# device.operatingSystem                                   0.189980
# device.operatingSystemVersion                                 NaN
# device.screenColors                                           NaN
# device.screenResolution                                       NaN
# geoNetwork.city                                         -0.068956
# geoNetwork.cityId                                             NaN
# geoNetwork.continent                                    -0.025988
# geoNetwork.country                                      -0.036391
# geoNetwork.latitude                                           NaN
# geoNetwork.longitude                                          NaN
# geoNetwork.metro                                        -0.001635
# geoNetwork.networkDomain                                -0.074091
# geoNetwork.networkLocation                                    NaN
# geoNetwork.region                                        0.020394
# geoNetwork.subContinent                                 -0.016916
# totals.bounces                                                NaN
# totals.hits                                              0.062747
# totals.newVisits                                              NaN
# totals.pageviews                                         0.065405
# totals.visits                                                 NaN
# trafficSource.adContent                                  0.018338
# trafficSource.adwordsClickInfo.adNetworkType             0.005658
# trafficSource.adwordsClickInfo.criteriaParameters             NaN
# trafficSource.adwordsClickInfo.gclId                     0.012677
# trafficSource.adwordsClickInfo.isVideoAd                 0.005699
# trafficSource.adwordsClickInfo.page                      0.005760
# trafficSource.adwordsClickInfo.slot                      0.006929
# trafficSource.isTrueDirect                              -0.074998
# trafficSource.keyword                                   -0.010758
# trafficSource.medium                                    -0.028540
# trafficSource.referralPath                              -0.073393
# trafficSource.source                                    -0.039166
# sess_date_dow                                           -0.037614
# sess_date_hours                                          0.039538
# sess_date_dom                                           -0.011544
# next_session_1                                           0.066677
# next_session_2                                           0.066634
# nb_pageviews                                            -0.017161
# ratio_pageviews                                          0.058958
#
#                                                    device.browserSize  \
# channelGrouping                                                   NaN
# socialEngagementType                                              NaN
# visitId                                                           NaN
# visitNumber                                                       NaN
# visitStartTime                                                    NaN
# device.browser                                                    NaN
# device.browserSize                                                NaN
# device.browserVersion                                             NaN
# device.deviceCategory                                             NaN
# device.flashVersion                                               NaN
# device.isMobile                                                   NaN
# device.language                                                   NaN
# device.mobileDeviceBranding                                       NaN
# device.mobileDeviceInfo                                           NaN
# device.mobileDeviceMarketingName                                  NaN
# device.mobileDeviceModel                                          NaN
# device.mobileInputSelector                                        NaN
# device.operatingSystem                                            NaN
# device.operatingSystemVersion                                     NaN
# device.screenColors                                               NaN
# device.screenResolution                                           NaN
# geoNetwork.city                                                   NaN
# geoNetwork.cityId                                                 NaN
# geoNetwork.continent                                              NaN
# geoNetwork.country                                                NaN
# geoNetwork.latitude                                               NaN
# geoNetwork.longitude                                              NaN
# geoNetwork.metro                                                  NaN
# geoNetwork.networkDomain                                          NaN
# geoNetwork.networkLocation                                        NaN
# geoNetwork.region                                                 NaN
# geoNetwork.subContinent                                           NaN
# totals.bounces                                                    NaN
# totals.hits                                                       NaN
# totals.newVisits                                                  NaN
# totals.pageviews                                                  NaN
# totals.visits                                                     NaN
# trafficSource.adContent                                           NaN
# trafficSource.adwordsClickInfo.adNetworkType                      NaN
# trafficSource.adwordsClickInfo.criteriaParameters                 NaN
# trafficSource.adwordsClickInfo.gclId                              NaN
# trafficSource.adwordsClickInfo.isVideoAd                          NaN
# trafficSource.adwordsClickInfo.page                               NaN
# trafficSource.adwordsClickInfo.slot                               NaN
# trafficSource.isTrueDirect                                        NaN
# trafficSource.keyword                                             NaN
# trafficSource.medium                                              NaN
# trafficSource.referralPath                                        NaN
# trafficSource.source                                              NaN
# sess_date_dow                                                     NaN
# sess_date_hours                                                   NaN
# sess_date_dom                                                     NaN
# next_session_1                                                    NaN
# next_session_2                                                    NaN
# nb_pageviews                                                      NaN
# ratio_pageviews                                                   NaN
#
#                                                    device.browserVersion  \
# channelGrouping                                                      NaN
# socialEngagementType                                                 NaN
# visitId                                                              NaN
# visitNumber                                                          NaN
# visitStartTime                                                       NaN
# device.browser                                                       NaN
# device.browserSize                                                   NaN
# device.browserVersion                                                NaN
# device.deviceCategory                                                NaN
# device.flashVersion                                                  NaN
# device.isMobile                                                      NaN
# device.language                                                      NaN
# device.mobileDeviceBranding                                          NaN
# device.mobileDeviceInfo                                              NaN
# device.mobileDeviceMarketingName                                     NaN
# device.mobileDeviceModel                                             NaN
# device.mobileInputSelector                                           NaN
# device.operatingSystem                                               NaN
# device.operatingSystemVersion                                        NaN
# device.screenColors                                                  NaN
# device.screenResolution                                              NaN
# geoNetwork.city                                                      NaN
# geoNetwork.cityId                                                    NaN
# geoNetwork.continent                                                 NaN
# geoNetwork.country                                                   NaN
# geoNetwork.latitude                                                  NaN
# geoNetwork.longitude                                                 NaN
# geoNetwork.metro                                                     NaN
# geoNetwork.networkDomain                                             NaN
# geoNetwork.networkLocation                                           NaN
# geoNetwork.region                                                    NaN
# geoNetwork.subContinent                                              NaN
# totals.bounces                                                       NaN
# totals.hits                                                          NaN
# totals.newVisits                                                     NaN
# totals.pageviews                                                     NaN
# totals.visits                                                        NaN
# trafficSource.adContent                                              NaN
# trafficSource.adwordsClickInfo.adNetworkType                         NaN
# trafficSource.adwordsClickInfo.criteriaParameters                    NaN
# trafficSource.adwordsClickInfo.gclId                                 NaN
# trafficSource.adwordsClickInfo.isVideoAd                             NaN
# trafficSource.adwordsClickInfo.page                                  NaN
# trafficSource.adwordsClickInfo.slot                                  NaN
# trafficSource.isTrueDirect                                           NaN
# trafficSource.keyword                                                NaN
# trafficSource.medium                                                 NaN
# trafficSource.referralPath                                           NaN
# trafficSource.source                                                 NaN
# sess_date_dow                                                        NaN
# sess_date_hours                                                      NaN
# sess_date_dom                                                        NaN
# next_session_1                                                       NaN
# next_session_2                                                       NaN
# nb_pageviews                                                         NaN
# ratio_pageviews                                                      NaN
#
#                                                    device.deviceCategory  \
# channelGrouping                                                -0.219050
# socialEngagementType                                                 NaN
# visitId                                                         0.139118
# visitNumber                                                    -0.038334
# visitStartTime                                                  0.139118
# device.browser                                                 -0.227155
# device.browserSize                                                   NaN
# device.browserVersion                                                NaN
# device.deviceCategory                                           1.000000
# device.flashVersion                                                  NaN
# device.isMobile                                                 0.945925
# device.language                                                      NaN
# device.mobileDeviceBranding                                          NaN
# device.mobileDeviceInfo                                              NaN
# device.mobileDeviceMarketingName                                     NaN
# device.mobileDeviceModel                                             NaN
# device.mobileInputSelector                                           NaN
# device.operatingSystem                                         -0.691018
# device.operatingSystemVersion                                        NaN
# device.screenColors                                                  NaN
# device.screenResolution                                              NaN
# geoNetwork.city                                                 0.058018
# geoNetwork.cityId                                                    NaN
# geoNetwork.continent                                           -0.002335
# geoNetwork.country                                             -0.075542
# geoNetwork.latitude                                                  NaN
# geoNetwork.longitude                                                 NaN
# geoNetwork.metro                                                0.072978
# geoNetwork.networkDomain                                       -0.025516
# geoNetwork.networkLocation                                           NaN
# geoNetwork.region                                              -0.011552
# geoNetwork.subContinent                                        -0.025759
# totals.bounces                                                       NaN
# totals.hits                                                    -0.022319
# totals.newVisits                                                     NaN
# totals.pageviews                                               -0.023268
# totals.visits                                                        NaN
# trafficSource.adContent                                        -0.085514
# trafficSource.adwordsClickInfo.adNetworkType                   -0.092311
# trafficSource.adwordsClickInfo.criteriaParameters                    NaN
# trafficSource.adwordsClickInfo.gclId                           -0.084562
# trafficSource.adwordsClickInfo.isVideoAd                       -0.092341
# trafficSource.adwordsClickInfo.page                            -0.092265
# trafficSource.adwordsClickInfo.slot                            -0.093945
# trafficSource.isTrueDirect                                     -0.061888
# trafficSource.keyword                                          -0.188551
# trafficSource.medium                                           -0.160634
# trafficSource.referralPath                                      0.024073
# trafficSource.source                                            0.061462
# sess_date_dow                                                   0.075410
# sess_date_hours                                                -0.028118
# sess_date_dom                                                  -0.030068
# next_session_1                                                  0.000645
# next_session_2                                                  0.000658
# nb_pageviews                                                   -0.137838
# ratio_pageviews                                                -0.003167
#
#                                                    device.flashVersion  \
# channelGrouping                                                    NaN
# socialEngagementType                                               NaN
# visitId                                                            NaN
# visitNumber                                                        NaN
# visitStartTime                                                     NaN
# device.browser                                                     NaN
# device.browserSize                                                 NaN
# device.browserVersion                                              NaN
# device.deviceCategory                                              NaN
# device.flashVersion                                                NaN
# device.isMobile                                                    NaN
# device.language                                                    NaN
# device.mobileDeviceBranding                                        NaN
# device.mobileDeviceInfo                                            NaN
# device.mobileDeviceMarketingName                                   NaN
# device.mobileDeviceModel                                           NaN
# device.mobileInputSelector                                         NaN
# device.operatingSystem                                             NaN
# device.operatingSystemVersion                                      NaN
# device.screenColors                                                NaN
# device.screenResolution                                            NaN
# geoNetwork.city                                                    NaN
# geoNetwork.cityId                                                  NaN
# geoNetwork.continent                                               NaN
# geoNetwork.country                                                 NaN
# geoNetwork.latitude                                                NaN
# geoNetwork.longitude                                               NaN
# geoNetwork.metro                                                   NaN
# geoNetwork.networkDomain                                           NaN
# geoNetwork.networkLocation                                         NaN
# geoNetwork.region                                                  NaN
# geoNetwork.subContinent                                            NaN
# totals.bounces                                                     NaN
# totals.hits                                                        NaN
# totals.newVisits                                                   NaN
# totals.pageviews                                                   NaN
# totals.visits                                                      NaN
# trafficSource.adContent                                            NaN
# trafficSource.adwordsClickInfo.adNetworkType                       NaN
# trafficSource.adwordsClickInfo.criteriaParameters                  NaN
# trafficSource.adwordsClickInfo.gclId                               NaN
# trafficSource.adwordsClickInfo.isVideoAd                           NaN
# trafficSource.adwordsClickInfo.page                                NaN
# trafficSource.adwordsClickInfo.slot                                NaN
# trafficSource.isTrueDirect                                         NaN
# trafficSource.keyword                                              NaN
# trafficSource.medium                                               NaN
# trafficSource.referralPath                                         NaN
# trafficSource.source                                               NaN
# sess_date_dow                                                      NaN
# sess_date_hours                                                    NaN
# sess_date_dom                                                      NaN
# next_session_1                                                     NaN
# next_session_2                                                     NaN
# nb_pageviews                                                       NaN
# ratio_pageviews                                                    NaN
#
#                                                         ...         \
# channelGrouping                                         ...
# socialEngagementType                                    ...
# visitId                                                 ...
# visitNumber                                             ...
# visitStartTime                                          ...
# device.browser                                          ...
# device.browserSize                                      ...
# device.browserVersion                                   ...
# device.deviceCategory                                   ...
# device.flashVersion                                     ...
# device.isMobile                                         ...
# device.language                                         ...
# device.mobileDeviceBranding                             ...
# device.mobileDeviceInfo                                 ...
# device.mobileDeviceMarketingName                        ...
# device.mobileDeviceModel                                ...
# device.mobileInputSelector                              ...
# device.operatingSystem                                  ...
# device.operatingSystemVersion                           ...
# device.screenColors                                     ...
# device.screenResolution                                 ...
# geoNetwork.city                                         ...
# geoNetwork.cityId                                       ...
# geoNetwork.continent                                    ...
# geoNetwork.country                                      ...
# geoNetwork.latitude                                     ...
# geoNetwork.longitude                                    ...
# geoNetwork.metro                                        ...
# geoNetwork.networkDomain                                ...
# geoNetwork.networkLocation                              ...
# geoNetwork.region                                       ...
# geoNetwork.subContinent                                 ...
# totals.bounces                                          ...
# totals.hits                                             ...
# totals.newVisits                                        ...
# totals.pageviews                                        ...
# totals.visits                                           ...
# trafficSource.adContent                                 ...
# trafficSource.adwordsClickInfo.adNetworkType            ...
# trafficSource.adwordsClickInfo.criteriaParameters       ...
# trafficSource.adwordsClickInfo.gclId                    ...
# trafficSource.adwordsClickInfo.isVideoAd                ...
# trafficSource.adwordsClickInfo.page                     ...
# trafficSource.adwordsClickInfo.slot                     ...
# trafficSource.isTrueDirect                              ...
# trafficSource.keyword                                   ...
# trafficSource.medium                                    ...
# trafficSource.referralPath                              ...
# trafficSource.source                                    ...
# sess_date_dow                                           ...
# sess_date_hours                                         ...
# sess_date_dom                                           ...
# next_session_1                                          ...
# next_session_2                                          ...
# nb_pageviews                                            ...
# ratio_pageviews                                         ...
#
#                                                    trafficSource.medium  \
# channelGrouping                                                0.820530
# socialEngagementType                                                NaN
# visitId                                                       -0.090602
# visitNumber                                                   -0.035906
# visitStartTime                                                -0.090603
# device.browser                                                -0.028540
# device.browserSize                                                  NaN
# device.browserVersion                                               NaN
# device.deviceCategory                                         -0.160634
# device.flashVersion                                                 NaN
# device.isMobile                                               -0.176099
# device.language                                                     NaN
# device.mobileDeviceBranding                                         NaN
# device.mobileDeviceInfo                                             NaN
# device.mobileDeviceMarketingName                                    NaN
# device.mobileDeviceModel                                            NaN
# device.mobileInputSelector                                          NaN
# device.operatingSystem                                         0.151714
# device.operatingSystemVersion                                       NaN
# device.screenColors                                                 NaN
# device.screenResolution                                             NaN
# geoNetwork.city                                                0.064913
# geoNetwork.cityId                                                   NaN
# geoNetwork.continent                                           0.073413
# geoNetwork.country                                             0.115910
# geoNetwork.latitude                                                 NaN
# geoNetwork.longitude                                                NaN
# geoNetwork.metro                                               0.018832
# geoNetwork.networkDomain                                       0.043257
# geoNetwork.networkLocation                                          NaN
# geoNetwork.region                                              0.039109
# geoNetwork.subContinent                                       -0.020936
# totals.bounces                                                      NaN
# totals.hits                                                   -0.028749
# totals.newVisits                                                    NaN
# totals.pageviews                                              -0.029279
# totals.visits                                                       NaN
# trafficSource.adContent                                        0.061852
# trafficSource.adwordsClickInfo.adNetworkType                   0.113363
# trafficSource.adwordsClickInfo.criteriaParameters                   NaN
# trafficSource.adwordsClickInfo.gclId                           0.099937
# trafficSource.adwordsClickInfo.isVideoAd                       0.113368
# trafficSource.adwordsClickInfo.page                            0.113341
# trafficSource.adwordsClickInfo.slot                            0.112376
# trafficSource.isTrueDirect                                     0.609524
# trafficSource.keyword                                         -0.135192
# trafficSource.medium                                           1.000000
# trafficSource.referralPath                                     0.003025
# trafficSource.source                                           0.671765
# sess_date_dow                                                  0.019171
# sess_date_hours                                               -0.018323
# sess_date_dom                                                  0.001000
# next_session_1                                                -0.044304
# next_session_2                                                -0.093220
# nb_pageviews                                                   0.031972
# ratio_pageviews                                               -0.026044
#
#                                                    trafficSource.referralPath  \
# channelGrouping                                                      0.050845
# socialEngagementType                                                      NaN
# visitId                                                             -0.050508
# visitNumber                                                         -0.015744
# visitStartTime                                                      -0.050508
# device.browser                                                      -0.073393
# device.browserSize                                                        NaN
# device.browserVersion                                                     NaN
# device.deviceCategory                                                0.024073
# device.flashVersion                                                       NaN
# device.isMobile                                                      0.023809
# device.language                                                           NaN
# device.mobileDeviceBranding                                               NaN
# device.mobileDeviceInfo                                                   NaN
# device.mobileDeviceMarketingName                                          NaN
# device.mobileDeviceModel                                                  NaN
# device.mobileInputSelector                                                NaN
# device.operatingSystem                                               0.038202
# device.operatingSystemVersion                                             NaN
# device.screenColors                                                       NaN
# device.screenResolution                                                   NaN
# geoNetwork.city                                                      0.070143
# geoNetwork.cityId                                                         NaN
# geoNetwork.continent                                                 0.054256
# geoNetwork.country                                                   0.028572
# geoNetwork.latitude                                                       NaN
# ...
# sess_date_dom                                           1.000000
# next_session_1                                         -0.009031
# next_session_2                                         -0.000619
# nb_pageviews                                            0.067122
# ratio_pageviews                                        -0.003459
#
#                                                    next_session_1  \
# channelGrouping                                         -0.067592
# socialEngagementType                                          NaN
# visitId                                                  0.030948
# visitNumber                                              0.273839
# visitStartTime                                           0.030948
# device.browser                                           0.066677
# device.browserSize                                            NaN
# device.browserVersion                                         NaN
# device.deviceCategory                                    0.000645
# device.flashVersion                                           NaN
# device.isMobile                                          0.002686
# device.language                                               NaN
# device.mobileDeviceBranding                                   NaN
# device.mobileDeviceInfo                                       NaN
# device.mobileDeviceMarketingName                              NaN
# device.mobileDeviceModel                                      NaN
# device.mobileInputSelector                                    NaN
# device.operatingSystem                                  -0.042475
# device.operatingSystemVersion                                 NaN
# device.screenColors                                           NaN
# device.screenResolution                                       NaN
# geoNetwork.city                                         -0.069483
# geoNetwork.cityId                                             NaN
# geoNetwork.continent                                    -0.093103
# geoNetwork.country                                      -0.099699
# geoNetwork.latitude                                           NaN
# geoNetwork.longitude                                          NaN
# geoNetwork.metro                                        -0.000031
# geoNetwork.networkDomain                                -0.073144
# geoNetwork.networkLocation                                    NaN
# geoNetwork.region                                        0.025237
# geoNetwork.subContinent                                  0.060226
# totals.bounces                                                NaN
# totals.hits                                              0.073166
# totals.newVisits                                              NaN
# totals.pageviews                                         0.074894
# totals.visits                                                 NaN
# trafficSource.adContent                                 -0.012298
# trafficSource.adwordsClickInfo.adNetworkType            -0.033060
# trafficSource.adwordsClickInfo.criteriaParameters             NaN
# trafficSource.adwordsClickInfo.gclId                    -0.029197
# trafficSource.adwordsClickInfo.isVideoAd                -0.033045
# trafficSource.adwordsClickInfo.page                     -0.032960
# trafficSource.adwordsClickInfo.slot                     -0.033343
# trafficSource.isTrueDirect                              -0.373968
# trafficSource.keyword                                   -0.018936
# trafficSource.medium                                    -0.044304
# trafficSource.referralPath                              -0.050038
# trafficSource.source                                    -0.045068
# sess_date_dow                                           -0.013390
# sess_date_hours                                          0.020008
# sess_date_dom                                           -0.009031
# next_session_1                                           1.000000
# next_session_2                                           0.211296
# nb_pageviews                                             0.003401
# ratio_pageviews                                          0.065183
#
#                                                    next_session_2  \
# channelGrouping                                         -0.102199
# socialEngagementType                                          NaN
# visitId                                                  0.004611
# visitNumber                                              0.204823
# visitStartTime                                           0.004611
# device.browser                                           0.066634
# device.browserSize                                            NaN
# device.browserVersion                                         NaN
# device.deviceCategory                                    0.000658
# device.flashVersion                                           NaN
# device.isMobile                                          0.002995
# device.language                                               NaN
# device.mobileDeviceBranding                                   NaN
# device.mobileDeviceInfo                                       NaN
# device.mobileDeviceMarketingName                              NaN
# device.mobileDeviceModel                                      NaN
# device.mobileInputSelector                                    NaN
# device.operatingSystem                                  -0.042685
# device.operatingSystemVersion                                 NaN
# device.screenColors                                           NaN
# device.screenResolution                                       NaN
# geoNetwork.city                                         -0.070778
# geoNetwork.cityId                                             NaN
# geoNetwork.continent                                    -0.092949
# geoNetwork.country                                      -0.099320
# geoNetwork.latitude                                           NaN
# geoNetwork.longitude                                          NaN
# geoNetwork.metro                                        -0.003289
# geoNetwork.networkDomain                                -0.076007
# geoNetwork.networkLocation                                    NaN
# geoNetwork.region                                        0.025088
# geoNetwork.subContinent                                  0.059943
# totals.bounces                                                NaN
# totals.hits                                              0.113208
# totals.newVisits                                              NaN
# totals.pageviews                                         0.116274
# totals.visits                                                 NaN
# trafficSource.adContent                                 -0.010463
# trafficSource.adwordsClickInfo.adNetworkType            -0.058312
# trafficSource.adwordsClickInfo.criteriaParameters             NaN
# trafficSource.adwordsClickInfo.gclId                    -0.054619
# trafficSource.adwordsClickInfo.isVideoAd                -0.058292
# trafficSource.adwordsClickInfo.page                     -0.058193
# trafficSource.adwordsClickInfo.slot                     -0.057326
# trafficSource.isTrueDirect                              -0.202417
# trafficSource.keyword                                   -0.011675
# trafficSource.medium                                    -0.093220
# trafficSource.referralPath                              -0.042194
# trafficSource.source                                    -0.072314
# sess_date_dow                                           -0.033651
# sess_date_hours                                          0.039009
# sess_date_dom                                           -0.000619
# next_session_1                                           0.211296
# next_session_2                                           1.000000
# nb_pageviews                                             0.015865
# ratio_pageviews                                          0.103111
#
#                                                    nb_pageviews  \
# channelGrouping                                        0.124799
# socialEngagementType                                        NaN
# visitId                                               -0.585317
# visitNumber                                            0.009575
# visitStartTime                                        -0.585317
# device.browser                                        -0.017161
# device.browserSize                                          NaN
# device.browserVersion                                       NaN
# device.deviceCategory                                 -0.137838
# device.flashVersion                                         NaN
# device.isMobile                                       -0.146715
# device.language                                             NaN
# device.mobileDeviceBranding                                 NaN
# device.mobileDeviceInfo                                     NaN
# device.mobileDeviceMarketingName                            NaN
# device.mobileDeviceModel                                    NaN
# device.mobileInputSelector                                  NaN
# device.operatingSystem                                 0.079472
# device.operatingSystemVersion                               NaN
# device.screenColors                                         NaN
# device.screenResolution                                     NaN
# geoNetwork.city                                       -0.047626
# geoNetwork.cityId                                           NaN
# geoNetwork.continent                                  -0.031939
# geoNetwork.country                                     0.012902
# geoNetwork.latitude                                         NaN
# geoNetwork.longitude                                        NaN
# geoNetwork.metro                                      -0.079224
# geoNetwork.networkDomain                               0.003087
# geoNetwork.networkLocation                                  NaN
# geoNetwork.region                                      0.008975
# geoNetwork.subContinent                                0.062367
# totals.bounces                                              NaN
# totals.hits                                            0.027797
# totals.newVisits                                            NaN
# totals.pageviews                                       0.026056
# totals.visits                                               NaN
# trafficSource.adContent                                0.085634
# trafficSource.adwordsClickInfo.adNetworkType           0.034367
# trafficSource.adwordsClickInfo.criteriaParameters           NaN
# trafficSource.adwordsClickInfo.gclId                   0.020727
# trafficSource.adwordsClickInfo.isVideoAd               0.034312
# trafficSource.adwordsClickInfo.page                    0.034365
# trafficSource.adwordsClickInfo.slot                    0.034347
# trafficSource.isTrueDirect                            -0.013693
# trafficSource.keyword                                  0.139787
# trafficSource.medium                                   0.031972
# trafficSource.referralPath                             0.008762
# trafficSource.source                                  -0.094238
# sess_date_dow                                         -0.369843
# sess_date_hours                                        0.004189
# sess_date_dom                                          0.067122
# next_session_1                                         0.003401
# next_session_2                                         0.015865
# nb_pageviews                                           1.000000
# ratio_pageviews                                       -0.135908
#
#                                                    ratio_pageviews
# channelGrouping                                          -0.072485
# socialEngagementType                                           NaN
# visitId                                                   0.070042
# visitNumber                                               0.037563
# visitStartTime                                            0.070042
# device.browser                                            0.058958
# device.browserSize                                             NaN
# device.browserVersion                                          NaN
# device.deviceCategory                                    -0.003167
# device.flashVersion                                            NaN
# device.isMobile                                          -0.005677
# device.language                                                NaN
# device.mobileDeviceBranding                                    NaN
# device.mobileDeviceInfo                                        NaN
# device.mobileDeviceMarketingName                               NaN
# device.mobileDeviceModel                                       NaN
# device.mobileInputSelector                                     NaN
# device.operatingSystem                                   -0.049136
# device.operatingSystemVersion                                  NaN
# device.screenColors                                            NaN
# device.screenResolution                                        NaN
# geoNetwork.city                                          -0.033424
# geoNetwork.cityId                                              NaN
# geoNetwork.continent                                     -0.135069
# geoNetwork.country                                       -0.141734
# geoNetwork.latitude                                            NaN
# geoNetwork.longitude                                           NaN
# geoNetwork.metro                                          0.050734
# geoNetwork.networkDomain                                 -0.075629
# geoNetwork.networkLocation                                     NaN
# geoNetwork.region                                         0.046897
# geoNetwork.subContinent                                   0.077033
# totals.bounces                                                 NaN
# totals.hits                                               0.918109
# totals.newVisits                                               NaN
# totals.pageviews                                          0.938947
# totals.visits                                                  NaN
# trafficSource.adContent                                  -0.025685
# trafficSource.adwordsClickInfo.adNetworkType             -0.045990
# trafficSource.adwordsClickInfo.criteriaParameters              NaN
# trafficSource.adwordsClickInfo.gclId                     -0.038718
# trafficSource.adwordsClickInfo.isVideoAd                 -0.045969
# trafficSource.adwordsClickInfo.page                      -0.046011
# trafficSource.adwordsClickInfo.slot                      -0.044141
# trafficSource.isTrueDirect                               -0.077050
# trafficSource.keyword                                    -0.043435
# trafficSource.medium                                     -0.026044
# trafficSource.referralPath                               -0.062148
# trafficSource.source                                     -0.029087
# sess_date_dow                                             0.049067
# sess_date_hours                                           0.017462
# sess_date_dom                                            -0.003459
# next_session_1                                            0.065183
# next_session_2                                            0.103111
# nb_pageviews                                             -0.135908
# ratio_pageviews                                           1.000000
#
# [56 rows x 56 columns]

# %%
cols_to_drop = ['trafficSource.campaignCode']
train = train.drop(cols_to_drop, axis=1, inplace = True)
test = test.drop(cols_to_drop, axis=1, inplace = True)

for f in categorical_features:
    train[f], indexer = pd.factorize(train[f])
    test[f] = indexer.get_indexer(test[f])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-51128363a96f> in <module>()
#       1 cols_to_drop = ['trafficSource.campaignCode']
# ----> 2 train = train.drop(cols_to_drop, axis=1, inplace = True)
#       3 test = test.drop(cols_to_drop, axis=1, inplace = True)
#       4
#       5 for f in categorical_features:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# -> 3108                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3109
#    3110         if inplace:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3138                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3139             else:
# -> 3140                 new_axis = axis.drop(labels, errors=errors)
#    3141             dropped = self.reindex(**{axis_name: new_axis})
#    3142             try:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4385             if errors != 'ignore':
#    4386                 raise KeyError(
# -> 4387                     'labels %s not contained in axis' % labels[mask])
#    4388             indexer = indexer[~mask]
#    4389         return self.delete(indexer)
#
# KeyError: "labels ['trafficSource.campaignCode'] not contained in axis"

# %%
import os

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error
import gc
import time
from pandas.core.common import SettingWithCopyWarning
import warnings
import lightgbm as lgb
from sklearn.model_selection import GroupKFold
import json
from pandas.io.json import json_normalize
# I don't like SettingWithCopyWarnings ...
warnings.simplefilter('error', SettingWithCopyWarning)
gc.enable()
# %matplotlib inline
from sklearn import preprocessing
gc.enable()

# %%
train = load_df('train.csv')
test = load_df('test.csv')

# %%
def get_folds(df=None, n_splits=5):
    """Returns dataframe indices corresponding to Visitors Group KFold"""
    # Get sorted unique visitors
    unique_vis = np.array(sorted(df['fullVisitorId'].unique()))

    # Get folds
    folds = GroupKFold(n_splits=n_splits)
    fold_ids = []
    ids = np.arange(df.shape[0])
    for trn_vis, val_vis in folds.split(X=unique_vis, y=unique_vis, groups=unique_vis):
        fold_ids.append(
            [
                ids[df['fullVisitorId'].isin(unique_vis[trn_vis])],
                ids[df['fullVisitorId'].isin(unique_vis[val_vis])]
            ]
        )

    return fold_ids

# %%
def load_df(csv_path='train.csv', nrows=None):
    JSON_COLUMNS = ['device', 'geoNetwork', 'totals', 'trafficSource']
    
    df = pd.read_csv(csv_path, 
                     converters={column: json.loads for column in JSON_COLUMNS}, 
                     dtype={'date': str, 'fullVisitorId': str, 'sessionId':str},
                     nrows=nrows)
    
    for column in JSON_COLUMNS:
        column_as_df = json_normalize(df[column])
        column_as_df.columns = [f"{column}.{subcolumn}" for subcolumn in column_as_df.columns]
        df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
    return df

# %%
train["totals.transactionRevenue"] = train["totals.transactionRevenue"].astype('float')
y_reg = train["totals.transactionRevenue"].fillna(0)
del train["totals.transactionRevenue"]

if "totals.transactionRevenue" in test.columns:
    del test["totals.transactionRevenue"]

# %%
train['target'] = y_reg
for df in [train, test]:
    df['vis_date'] = pd.to_datetime(df['visitStartTime'], unit='s')
    df['sess_date_dow'] = df['vis_date'].dt.dayofweek
    df['sess_date_hours'] = df['vis_date'].dt.hour
    df['sess_date_dom'] = df['vis_date'].dt.day
    df.sort_values(['fullVisitorId', 'vis_date'], ascending=True, inplace=True)
    df['next_session_1'] = (
        df['vis_date'] - df[['fullVisitorId', 'vis_date']].groupby('fullVisitorId')['vis_date'].shift(1)
    ).astype(np.int64) // 1e9 // 60 // 60
    df['next_session_2'] = (
        df['vis_date'] - df[['fullVisitorId', 'vis_date']].groupby('fullVisitorId')['vis_date'].shift(-1)
    ).astype(np.int64) // 1e9 // 60 // 60
    
#     df['max_visits'] = df['fullVisitorId'].map(
#         df[['fullVisitorId', 'visitNumber']].groupby('fullVisitorId')['visitNumber'].max()
#     )
    
    df['nb_pageviews'] = df['date'].map(
        df[['date', 'totals.pageviews']].groupby('date')['totals.pageviews'].sum()
    )
    
    df['ratio_pageviews'] = df['totals.pageviews'] / df['nb_pageviews']
    
#     df['nb_sessions'] = df['date'].map(
#         df[['date']].groupby('date').size()
#     )
    
#     df['nb_sessions_28_ma'] = df['date'].map(
#         df[['date']].groupby('date').size().rolling(28, min_periods=7).mean()
#     )

#     df['nb_sessions_28_ma'] = df['nb_sessions'] / df['nb_sessions_28_ma']

#     df['nb_sessions_per_day'] = df['date'].map(
#         df[['date']].groupby('date').size()
#     )
    
#     df['nb_visitors_per_day'] = df['date'].map(
#         df[['date','fullVisitorId']].groupby('date')['fullVisitorId'].nunique()
#     )

y_reg = train['target']
del train['target']

# %%
# second optimisation extra added
for df in [train, test]:
    df['date'] = pd.to_datetime(df['visitStartTime'], unit='s')
    df['sess_date_dow'] = df['date'].dt.dayofweek
    df['sess_date_hours'] = df['date'].dt.hour
    df['sess_date_dom'] = df['date'].dt.day
    
def browser_mapping(x):
    browsers = ['chrome','safari','firefox','internet explorer','edge','opera','coc coc','maxthon','iron']
    if x in browsers:
        return x.lower()
    elif  ('android' in x) or ('samsung' in x) or ('mini' in x) or ('iphone' in x) or ('in-app' in x) or ('playstation' in x):
        return 'mobile browser'
    elif  ('mozilla' in x) or ('chrome' in x) or ('blackberry' in x) or ('nokia' in x) or ('browser' in x) or ('amazon' in x):
        return 'mobile browser'
    elif  ('lunascape' in x) or ('netscape' in x) or ('blackberry' in x) or ('konqueror' in x) or ('puffin' in x) or ('amazon' in x):
        return 'mobile browser'
    elif '(not set)' in x:
        return x
    else:
        return 'others'
    
    
def adcontents_mapping(x):
    if  ('google' in x):
        return 'google'
    elif  ('placement' in x) | ('placememnt' in x):
        return 'placement'
    elif '(not set)' in x or 'nan' in x:
        return x
    elif 'ad' in x:
        return 'ad'
    else:
        return 'others'
    
def source_mapping(x):
    if  ('google' in x):
        return 'google'
    elif  ('youtube' in x):
        return 'youtube'
    elif '(not set)' in x or 'nan' in x:
        return x
    elif 'yahoo' in x:
        return 'yahoo'
    elif 'facebook' in x:
        return 'facebook'
    elif 'reddit' in x:
        return 'reddit'
    elif 'bing' in x:
        return 'bing'
    elif 'quora' in x:
        return 'quora'
    elif 'outlook' in x:
        return 'outlook'
    elif 'linkedin' in x:
        return 'linkedin'
    elif 'pinterest' in x:
        return 'pinterest'
    elif 'ask' in x:
        return 'ask'
    elif 'siliconvalley' in x:
        return 'siliconvalley'
    elif 'lunametrics' in x:
        return 'lunametrics'
    elif 'amazon' in x:
        return 'amazon'
    elif 'mysearch' in x:
        return 'mysearch'
    elif 'qiita' in x:
        return 'qiita'
    elif 'messenger' in x:
        return 'messenger'
    elif 'twitter' in x:
        return 'twitter'
    elif 't.co' in x:
        return 't.co'
    elif 'vk.com' in x:
        return 'vk.com'
    elif 'search' in x:
        return 'search'
    elif 'edu' in x:
        return 'edu'
    elif 'mail' in x:
        return 'mail'
    elif 'ad' in x:
        return 'ad'
    elif 'golang' in x:
        return 'golang'
    elif 'direct' in x:
        return 'direct'
    elif 'dealspotr' in x:
        return 'dealspotr'
    elif 'sashihara' in x:
        return 'sashihara'
    elif 'phandroid' in x:
        return 'phandroid'
    elif 'baidu' in x:
        return 'baidu'
    elif 'mdn' in x:
        return 'mdn'
    elif 'duckduckgo' in x:
        return 'duckduckgo'
    elif 'seroundtable' in x:
        return 'seroundtable'
    elif 'metrics' in x:
        return 'metrics'
    elif 'sogou' in x:
        return 'sogou'
    elif 'businessinsider' in x:
        return 'businessinsider'
    elif 'github' in x:
        return 'github'
    elif 'gophergala' in x:
        return 'gophergala'
    elif 'yandex' in x:
        return 'yandex'
    elif 'msn' in x:
        return 'msn'
    elif 'dfa' in x:
        return 'dfa'
    elif '(not set)' in x:
        return '(not set)'
    elif 'feedly' in x:
        return 'feedly'
    elif 'arstechnica' in x:
        return 'arstechnica'
    elif 'squishable' in x:
        return 'squishable'
    elif 'flipboard' in x:
        return 'flipboard'
    elif 't-online.de' in x:
        return 't-online.de'
    elif 'sm.cn' in x:
        return 'sm.cn'
    elif 'wow' in x:
        return 'wow'
    elif 'baidu' in x:
        return 'baidu'
    elif 'partners' in x:
        return 'partners'
    else:
        return 'others'

train['device.browser'] = train['device.browser'].map(lambda x:browser_mapping(str(x).lower())).astype('str')
train['trafficSource.adContent'] = train['trafficSource.adContent'].map(lambda x:adcontents_mapping(str(x).lower())).astype('str')
train['trafficSource.source'] = train['trafficSource.source'].map(lambda x:source_mapping(str(x).lower())).astype('str')

test['device.browser'] = test['device.browser'].map(lambda x:browser_mapping(str(x).lower())).astype('str')
test['trafficSource.adContent'] = test['trafficSource.adContent'].map(lambda x:adcontents_mapping(str(x).lower())).astype('str')
test['trafficSource.source'] = test['trafficSource.source'].map(lambda x:source_mapping(str(x).lower())).astype('str')

def process_device(data_df):
    print("process device ...")
    data_df['source.country'] = data_df['trafficSource.source'] + '_' + data_df['geoNetwork.country']
    data_df['campaign.medium'] = data_df['trafficSource.campaign'] + '_' + data_df['trafficSource.medium']
    data_df['browser.category'] = data_df['device.browser'] + '_' + data_df['device.deviceCategory']
    data_df['browser.os'] = data_df['device.browser'] + '_' + data_df['device.operatingSystem']
    return data_df

train = process_device(train)
test = process_device(test)

def custom(data):
    print('custom..')
    data['device_deviceCategory_channelGrouping'] = data['device.deviceCategory'] + "_" + data['channelGrouping']
    data['channelGrouping_browser'] = data['device.browser'] + "_" + data['channelGrouping']
    data['channelGrouping_OS'] = data['device.operatingSystem'] + "_" + data['channelGrouping']
    
    for i in ['geoNetwork.city', 'geoNetwork.continent', 'geoNetwork.country','geoNetwork.metro', 'geoNetwork.networkDomain', 'geoNetwork.region','geoNetwork.subContinent']:
        for j in ['device.browser','device.deviceCategory', 'device.operatingSystem', 'trafficSource.source']:
            data[i + "_" + j] = data[i] + "_" + data[j]
    
    data['content.source'] = data['trafficSource.adContent'] + "_" + data['source.country']
    data['medium.source'] = data['trafficSource.medium'] + "_" + data['source.country']
    return data

train = custom(train)
test = custom(test)
# Out:
# process device ...
# process device ...
# custom..
# custom..

# %%
def ImputeMissingValues(train_df, test_df):
    
    cat_cols = ['totals.pageviews']

    for col in cat_cols:
        print(col)
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(train_df[col].values.astype('str')) + list(test_df[col].values.astype('str')))
        train_df[col] = lbl.transform(list(train_df[col].values.astype('str')))
        test_df[col] = lbl.transform(list(test_df[col].values.astype('str')))

# %%
ImputeMissingValues(train,test)
# Out:
# totals.pageviews

# %%
excluded_features = [
    'date', 'fullVisitorId', 'sessionId', 'totals.transactionRevenue', 
    'visitId', 'visitStartTime', 'vis_date', 'nb_sessions', 'max_visits', 'trafficSource.campaignCode'
]

categorical_features = [
    _f for _f in train.columns
    if (_f not in excluded_features) & (train[_f].dtype == 'object')
]

# %%
for f in categorical_features:
    train[f], indexer = pd.factorize(train[f])
    test[f] = indexer.get_indexer(test[f])

# %%
train = train.drop(["trafficSource.campaignCode"], axis = 1)

# %%
folds = get_folds(df=train, n_splits=5)

train_features = [_f for _f in train.columns if _f not in excluded_features]
print(train_features)

importances = pd.DataFrame()
oof_reg_preds = np.zeros(train.shape[0])
sub_reg_preds = np.zeros(test.shape[0])
for fold_, (trn_, val_) in enumerate(folds):
    trn_x, trn_y = train[train_features].iloc[trn_], y_reg.iloc[trn_]
    val_x, val_y = train[train_features].iloc[val_], y_reg.iloc[val_]
    
    reg = lgb.LGBMRegressor(
        num_leaves=31,
        learning_rate=0.03,
        n_estimators=2000,
        subsample=.9,
        colsample_bytree=.9,
        random_state=1
    )
    reg.fit(
        trn_x, np.log1p(trn_y),
        eval_set=[(val_x, np.log1p(val_y))],
        early_stopping_rounds=50,
        verbose=100,
        eval_metric='rmse'
    )
    imp_df = pd.DataFrame()
    imp_df['feature'] = train_features
    imp_df['gain'] = reg.booster_.feature_importance(importance_type='gain')
    
    imp_df['fold'] = fold_ + 1
    importances = pd.concat([importances, imp_df], axis=0, sort=False)
    
    oof_reg_preds[val_] = reg.predict(val_x, num_iteration=reg.best_iteration_)
    oof_reg_preds[oof_reg_preds < 0] = 0
    _preds = reg.predict(test[train_features], num_iteration=reg.best_iteration_)
    _preds[_preds < 0] = 0
    sub_reg_preds += np.expm1(_preds) / len(folds)
    
mean_squared_error(np.log1p(y_reg), oof_reg_preds) ** .5
# Out:
# ['channelGrouping', 'socialEngagementType', 'visitNumber', 'device.browser', 'device.browserSize', 'device.browserVersion', 'device.deviceCategory', 'device.flashVersion', 'device.isMobile', 'device.language', 'device.mobileDeviceBranding', 'device.mobileDeviceInfo', 'device.mobileDeviceMarketingName', 'device.mobileDeviceModel', 'device.mobileInputSelector', 'device.operatingSystem', 'device.operatingSystemVersion', 'device.screenColors', 'device.screenResolution', 'geoNetwork.city', 'geoNetwork.cityId', 'geoNetwork.continent', 'geoNetwork.country', 'geoNetwork.latitude', 'geoNetwork.longitude', 'geoNetwork.metro', 'geoNetwork.networkDomain', 'geoNetwork.networkLocation', 'geoNetwork.region', 'geoNetwork.subContinent', 'totals.bounces', 'totals.hits', 'totals.newVisits', 'totals.pageviews', 'totals.visits', 'trafficSource.adContent', 'trafficSource.adwordsClickInfo.adNetworkType', 'trafficSource.adwordsClickInfo.criteriaParameters', 'trafficSource.adwordsClickInfo.gclId', 'trafficSource.adwordsClickInfo.isVideoAd', 'trafficSource.adwordsClickInfo.page', 'trafficSource.adwordsClickInfo.slot', 'trafficSource.campaign', 'trafficSource.isTrueDirect', 'trafficSource.keyword', 'trafficSource.medium', 'trafficSource.referralPath', 'trafficSource.source', 'sess_date_dow', 'sess_date_hours', 'sess_date_dom', 'source.country', 'campaign.medium', 'browser.category', 'browser.os', 'device_deviceCategory_channelGrouping', 'channelGrouping_browser', 'channelGrouping_OS', 'geoNetwork.city_device.browser', 'geoNetwork.city_device.deviceCategory', 'geoNetwork.city_device.operatingSystem', 'geoNetwork.city_trafficSource.source', 'geoNetwork.continent_device.browser', 'geoNetwork.continent_device.deviceCategory', 'geoNetwork.continent_device.operatingSystem', 'geoNetwork.continent_trafficSource.source', 'geoNetwork.country_device.browser', 'geoNetwork.country_device.deviceCategory', 'geoNetwork.country_device.operatingSystem', 'geoNetwork.country_trafficSource.source', 'geoNetwork.metro_device.browser', 'geoNetwork.metro_device.deviceCategory', 'geoNetwork.metro_device.operatingSystem', 'geoNetwork.metro_trafficSource.source', 'geoNetwork.networkDomain_device.browser', 'geoNetwork.networkDomain_device.deviceCategory', 'geoNetwork.networkDomain_device.operatingSystem', 'geoNetwork.networkDomain_trafficSource.source', 'geoNetwork.region_device.browser', 'geoNetwork.region_device.deviceCategory', 'geoNetwork.region_device.operatingSystem', 'geoNetwork.region_trafficSource.source', 'geoNetwork.subContinent_device.browser', 'geoNetwork.subContinent_device.deviceCategory', 'geoNetwork.subContinent_device.operatingSystem', 'geoNetwork.subContinent_trafficSource.source', 'content.source', 'medium.source']
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.66714	valid_0's l2: 2.77935
# [200]	valid_0's rmse: 1.65277	valid_0's l2: 2.73164
# [300]	valid_0's rmse: 1.64643	valid_0's l2: 2.71073
# [400]	valid_0's rmse: 1.64223	valid_0's l2: 2.69693
# [500]	valid_0's rmse: 1.64093	valid_0's l2: 2.69264
# [600]	valid_0's rmse: 1.6391	valid_0's l2: 2.68663
# Early stopping, best iteration is:
# [612]	valid_0's rmse: 1.63904	valid_0's l2: 2.68644
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.64538	valid_0's l2: 2.70726
# [200]	valid_0's rmse: 1.63694	valid_0's l2: 2.67958
# [300]	valid_0's rmse: 1.63501	valid_0's l2: 2.67327
# [400]	valid_0's rmse: 1.63409	valid_0's l2: 2.67025
# [500]	valid_0's rmse: 1.63306	valid_0's l2: 2.6669
# [600]	valid_0's rmse: 1.63113	valid_0's l2: 2.66057
# Early stopping, best iteration is:
# [636]	valid_0's rmse: 1.63039	valid_0's l2: 2.65818
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.66181	valid_0's l2: 2.76161
# [200]	valid_0's rmse: 1.65054	valid_0's l2: 2.72427
# [300]	valid_0's rmse: 1.64666	valid_0's l2: 2.71148
# [400]	valid_0's rmse: 1.64604	valid_0's l2: 2.70945
# [500]	valid_0's rmse: 1.645	valid_0's l2: 2.70602
# Early stopping, best iteration is:
# [501]	valid_0's rmse: 1.64498	valid_0's l2: 2.70597
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.63903	valid_0's l2: 2.68642
# [200]	valid_0's rmse: 1.63002	valid_0's l2: 2.65695
# [300]	valid_0's rmse: 1.62709	valid_0's l2: 2.64743
# [400]	valid_0's rmse: 1.62465	valid_0's l2: 2.63949
# Early stopping, best iteration is:
# [438]	valid_0's rmse: 1.6241	valid_0's l2: 2.63769
# Training until validation scores don't improve for 50 rounds.
# [100]	valid_0's rmse: 1.68182	valid_0's l2: 2.82851
# [200]	valid_0's rmse: 1.67159	valid_0's l2: 2.79421
# [300]	valid_0's rmse: 1.66667	valid_0's l2: 2.7778
# [400]	valid_0's rmse: 1.66436	valid_0's l2: 2.77011
# [500]	valid_0's rmse: 1.66331	valid_0's l2: 2.76661
# [600]	valid_0's rmse: 1.66285	valid_0's l2: 2.76508
# [700]	valid_0's rmse: 1.66154	valid_0's l2: 2.76073
# Early stopping, best iteration is:
# [691]	valid_0's rmse: 1.66143	valid_0's l2: 2.76035
# 1.6397945538063199

# %%
for col in ['visitNumber', 'totals.hits', 'totals.pageviews']:
    train[col] = train[col].astype(float)

# %%
train['predictions'] = np.expm1(oof_reg_preds)
test['predictions'] = sub_reg_preds

# %%
trn_data = train[train_features + ['fullVisitorId']].groupby('fullVisitorId').mean()

# %%
trn_pred_list = train[['fullVisitorId', 'predictions']].groupby('fullVisitorId')\
    .apply(lambda df: list(df.predictions))\
    .apply(lambda x: {'pred_'+str(i): pred for i, pred in enumerate(x)})

# %%
trn_all_predictions = pd.DataFrame(list(trn_pred_list.values), index=trn_data.index)
trn_feats = trn_all_predictions.columns
trn_all_predictions['t_mean'] = np.log1p(trn_all_predictions[trn_feats].mean(axis=1))
trn_all_predictions['t_median'] = np.log1p(trn_all_predictions[trn_feats].median(axis=1))
trn_all_predictions['t_sum_log'] = np.log1p(trn_all_predictions[trn_feats]).sum(axis=1)
trn_all_predictions['t_sum_act'] = np.log1p(trn_all_predictions[trn_feats].fillna(0).sum(axis=1))
trn_all_predictions['t_nb_sess'] = trn_all_predictions[trn_feats].isnull().sum(axis=1)
full_data = pd.concat([trn_data, trn_all_predictions], axis=1)
del trn_data, trn_all_predictions
gc.collect()
full_data.shape
# Out:
# (714167, 371)

# %%
sub_pred_list = test[['fullVisitorId', 'predictions']].groupby('fullVisitorId')\
    .apply(lambda df: list(df.predictions))\
    .apply(lambda x: {'pred_'+str(i): pred for i, pred in enumerate(x)})

# %%
sub_data = test[train_features + ['fullVisitorId']].groupby('fullVisitorId').mean()
sub_all_predictions = pd.DataFrame(list(sub_pred_list.values), index=sub_data.index)
for f in trn_feats:
    if f not in sub_all_predictions.columns:
        sub_all_predictions[f] = np.nan
sub_all_predictions['t_mean'] = np.log1p(sub_all_predictions[trn_feats].mean(axis=1))
sub_all_predictions['t_median'] = np.log1p(sub_all_predictions[trn_feats].median(axis=1))
sub_all_predictions['t_sum_log'] = np.log1p(sub_all_predictions[trn_feats]).sum(axis=1)
sub_all_predictions['t_sum_act'] = np.log1p(sub_all_predictions[trn_feats].fillna(0).sum(axis=1))
sub_all_predictions['t_nb_sess'] = sub_all_predictions[trn_feats].isnull().sum(axis=1)
sub_full_data = pd.concat([sub_data, sub_all_predictions], axis=1)
del sub_data, sub_all_predictions
gc.collect()
sub_full_data.shape
# Out:
# (617242, 371)

# %%
train['target'] = y_reg
trn_user_target = train[['fullVisitorId', 'target']].groupby('fullVisitorId').sum()

# %%
folds = get_folds(df=full_data[['totals.pageviews']].reset_index(), n_splits=5)

oof_preds = np.zeros(full_data.shape[0])
sub_preds = np.zeros(sub_full_data.shape[0])
vis_importances = pd.DataFrame()

for fold_, (trn_, val_) in enumerate(folds):
    trn_x, trn_y = full_data.iloc[trn_], trn_user_target['target'].iloc[trn_]
    val_x, val_y = full_data.iloc[val_], trn_user_target['target'].iloc[val_]
    
    reg = lgb.LGBMRegressor(
        num_leaves=31,
        learning_rate=0.03,
        n_estimators=1000,
        subsample=.9,
        colsample_bytree=.9,
        random_state=1
    )
    reg.fit(
        trn_x, np.log1p(trn_y),
        eval_set=[(trn_x, np.log1p(trn_y)), (val_x, np.log1p(val_y))],
        eval_names=['TRAIN', 'VALID'],
        early_stopping_rounds=50,
        eval_metric='rmse',
        verbose=100
    )
    
    imp_df = pd.DataFrame()
    imp_df['feature'] = trn_x.columns
    imp_df['gain'] = reg.booster_.feature_importance(importance_type='gain')
    
    imp_df['fold'] = fold_ + 1
    vis_importances = pd.concat([vis_importances, imp_df], axis=0, sort=False)
    
    oof_preds[val_] = reg.predict(val_x, num_iteration=reg.best_iteration_)
    oof_preds[oof_preds < 0] = 0
    
    # Make sure features are in the same order
    _preds = reg.predict(sub_full_data[full_data.columns], num_iteration=reg.best_iteration_)
    _preds[_preds < 0] = 0
    sub_preds += _preds / len(folds)
    
mean_squared_error(np.log1p(trn_user_target['target']), oof_preds) ** .5
# Out:
# Training until validation scores don't improve for 50 rounds.
# [100]	TRAIN's rmse: 1.545	TRAIN's l2: 2.38701	VALID's rmse: 1.58684	VALID's l2: 2.51805
# Early stopping, best iteration is:
# [143]	TRAIN's rmse: 1.52479	TRAIN's l2: 2.32498	VALID's rmse: 1.5835	VALID's l2: 2.50747
# Training until validation scores don't improve for 50 rounds.
# [100]	TRAIN's rmse: 1.54227	TRAIN's l2: 2.37859	VALID's rmse: 1.59509	VALID's l2: 2.54431
# Early stopping, best iteration is:
# [137]	TRAIN's rmse: 1.52415	TRAIN's l2: 2.32303	VALID's rmse: 1.5934	VALID's l2: 2.53893
# Training until validation scores don't improve for 50 rounds.
# [100]	TRAIN's rmse: 1.53995	TRAIN's l2: 2.37143	VALID's rmse: 1.60562	VALID's l2: 2.57803
# Early stopping, best iteration is:
# [130]	TRAIN's rmse: 1.52503	TRAIN's l2: 2.32572	VALID's rmse: 1.60445	VALID's l2: 2.57426
# Training until validation scores don't improve for 50 rounds.
# [100]	TRAIN's rmse: 1.54638	TRAIN's l2: 2.3913	VALID's rmse: 1.57782	VALID's l2: 2.48952
# [200]	TRAIN's rmse: 1.50845	TRAIN's l2: 2.27542	VALID's rmse: 1.57633	VALID's l2: 2.48481
# Early stopping, best iteration is:
# [162]	TRAIN's rmse: 1.51971	TRAIN's l2: 2.30953	VALID's rmse: 1.57614	VALID's l2: 2.48423
# Training until validation scores don't improve for 50 rounds.
# [100]	TRAIN's rmse: 1.53886	TRAIN's l2: 2.36809	VALID's rmse: 1.60352	VALID's l2: 2.57127
# [200]	TRAIN's rmse: 1.5001	TRAIN's l2: 2.2503	VALID's rmse: 1.60343	VALID's l2: 2.57098
# Early stopping, best iteration is:
# [162]	TRAIN's rmse: 1.51202	TRAIN's l2: 2.28621	VALID's rmse: 1.60238	VALID's l2: 2.56761
# 1.5920119231101837

# %%
sub_full_data['PredictedLogRevenue'] = sub_preds
sub_full_data[['PredictedLogRevenue']].to_csv('new_test.csv', index=True)
