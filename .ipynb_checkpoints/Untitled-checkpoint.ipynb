# %%
# used in Data processing
import pandas as pd
import numpy as np
import datetime as dt
# Visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt
from math import sin, cos, sqrt, atan2, radians
import os
import json

# %%
# %matplotlib inline

# %%
# Machine Learning
from sklearn.model_selection import train_test_split
from pandas.tseries.holiday import USFederalHolidayCalendar
# loads data frame
df = pd.read_csv("train.csv",nrows = 2_00_000)
# Out:
# /Users/vivek/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Machine Learning
from sklearn.model_selection import train_test_split
# loads data frame
df = pd.read_csv("train.csv",nrows = 2_00_000)
# Out:
# /Users/vivek/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Machine Learning
from sklearn.model_selection import train_test_split
from pandas.tseries.holiday import USFederalHolidayCalendar
# loads data frame
df = pd.read_csv("train.csv")
# Out:
# /Users/vivek/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = pd.read_csv("train.csv", dtype={'fullVisitorId': 'str'}, nrows = 2_00_000)

# %%
df.describe()
# Out:
#                date       visitId   visitNumber  visitStartTime
# count  2.000000e+05  2.000000e+05  200000.00000    2.000000e+05
# mean   2.016529e+07  1.484264e+09       2.24101    1.484264e+09
# std    4.678858e+03  8.784533e+06       9.19020    8.784533e+06
# min    2.016080e+07  1.470380e+09       1.00000    1.470380e+09
# 25%    2.016103e+07  1.477850e+09       1.00000    1.477850e+09
# 50%    2.016121e+07  1.481299e+09       1.00000    1.481299e+09
# 75%    2.017041e+07  1.491990e+09       1.00000    1.491990e+09
# max    2.017080e+07  1.501657e+09     389.00000    1.501657e+09

# %%
df.head()
# Out:
#   channelGrouping      date  \
# 0  Organic Search  20160902
# 1  Organic Search  20160902
# 2  Organic Search  20160902
# 3  Organic Search  20160902
# 4  Organic Search  20160902
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...  1131660440785968503
# 1  {"browser": "Firefox", "browserVersion": "not ...   377306020877927890
# 2  {"browser": "Chrome", "browserVersion": "not a...  3895546263509774583
# 3  {"browser": "UC Browser", "browserVersion": "n...  4763447161404445595
# 4  {"browser": "Chrome", "browserVersion": "not a...    27294437909732085
#
#                                           geoNetwork  \
# 0  {"continent": "Asia", "subContinent": "Western...
# 1  {"continent": "Oceania", "subContinent": "Aust...
# 2  {"continent": "Europe", "subContinent": "South...
# 3  {"continent": "Asia", "subContinent": "Southea...
# 4  {"continent": "Europe", "subContinent": "North...
#
# ...

# %%
library(tidyverse) # metapackage with lots of helpful functions
library(data.table)
library(jsonlite)
library(readr)
library(dplyr)
library(tidyr)
library(magrittr)
library(lubridate)
library(purrr)
library(ggplot2)
library(gridExtra)
library(countrycode)
library(highcharter)
library(ggExtra)
library(Hmisc)
library(caret)
library(ggalluvial)
library(xgboost)
library(knitr)
library(Rmisc)
library(scales)
library(glmnet)
library(keras)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-23dc89a8ae02> in <module>()
# ----> 1 library(tidyverse) # metapackage with lots of helpful functions
#       2 library(data.table)
#       3 library(jsonlite)
#       4 library(readr)
#       5 library(dplyr)
#
# NameError: name 'library' is not defined

# %%
library(caret)
library(lme4)
library(ggalluvial)
library(xgboost)
library(jsonlite)
library(lubridate)
library(knitr)
library(Rmisc)
library(scales)
library(countrycode)
library(highcharter)
library(glmnet)
library(keras)
library(forecast)
library(zoo)
library(magrittr)
library(tidyverse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-269a01da9b31> in <module>()
# ----> 1 library(caret)
#       2 library(lme4)
#       3 library(ggalluvial)
#       4 library(xgboost)
#       5 library(jsonlite)
#
# NameError: name 'library' is not defined

# %%
import library
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-20ad171fded9> in <module>()
# ----> 1 import library
#
# ModuleNotFoundError: No module named 'library'

# %%
import caret
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-c01007ec904d> in <module>()
# ----> 1 import caret
#
# ModuleNotFoundError: No module named 'caret'

# %%
library(caret)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-374e29f86c99> in <module>()
# ----> 1 library(caret)
#
# NameError: name 'library' is not defined

# %%
df.size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-5098ab42f864> in <module>()
# ----> 1 df.size()
#
# TypeError: 'numpy.int64' object is not callable

# %%
df.shape
# Out:
# (200000, 12)

# %%
df.head()
# Out:
#   channelGrouping      date  \
# 0  Organic Search  20160902
# 1  Organic Search  20160902
# 2  Organic Search  20160902
# 3  Organic Search  20160902
# 4  Organic Search  20160902
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...  1131660440785968503
# 1  {"browser": "Firefox", "browserVersion": "not ...   377306020877927890
# 2  {"browser": "Chrome", "browserVersion": "not a...  3895546263509774583
# 3  {"browser": "UC Browser", "browserVersion": "n...  4763447161404445595
# 4  {"browser": "Chrome", "browserVersion": "not a...    27294437909732085
#
#                                           geoNetwork  \
# 0  {"continent": "Asia", "subContinent": "Western...
# 1  {"continent": "Oceania", "subContinent": "Aust...
# 2  {"continent": "Europe", "subContinent": "South...
# 3  {"continent": "Asia", "subContinent": "Southea...
# 4  {"continent": "Europe", "subContinent": "North...
#
# ...

# %%
df.rows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-bab2f393c545> in <module>()
# ----> 1 df.rows()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
df.describe()
# Out:
#                date       visitId   visitNumber  visitStartTime
# count  2.000000e+05  2.000000e+05  200000.00000    2.000000e+05
# mean   2.016529e+07  1.484264e+09       2.24101    1.484264e+09
# std    4.678858e+03  8.784533e+06       9.19020    8.784533e+06
# min    2.016080e+07  1.470380e+09       1.00000    1.470380e+09
# 25%    2.016103e+07  1.477850e+09       1.00000    1.477850e+09
# 50%    2.016121e+07  1.481299e+09       1.00000    1.481299e+09
# 75%    2.017041e+07  1.491990e+09       1.00000    1.491990e+09
# max    2.017080e+07  1.501657e+09     389.00000    1.501657e+09

# %%
df.head()
# Out:
#   channelGrouping      date  \
# 0  Organic Search  20160902
# 1  Organic Search  20160902
# 2  Organic Search  20160902
# 3  Organic Search  20160902
# 4  Organic Search  20160902
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...  1131660440785968503
# 1  {"browser": "Firefox", "browserVersion": "not ...   377306020877927890
# 2  {"browser": "Chrome", "browserVersion": "not a...  3895546263509774583
# 3  {"browser": "UC Browser", "browserVersion": "n...  4763447161404445595
# 4  {"browser": "Chrome", "browserVersion": "not a...    27294437909732085
#
#                                           geoNetwork  \
# 0  {"continent": "Asia", "subContinent": "Western...
# 1  {"continent": "Oceania", "subContinent": "Aust...
# 2  {"continent": "Europe", "subContinent": "South...
# 3  {"continent": "Asia", "subContinent": "Southea...
# 4  {"continent": "Europe", "subContinent": "North...
#
# ...

# %%
df[(df['socialEngagementType'] != 'Socially Engaged')]
# Out:
#        channelGrouping      date  \
# 0       Organic Search  20160902
# 1       Organic Search  20160902
# 2       Organic Search  20160902
# 3       Organic Search  20160902
# 4       Organic Search  20160902
# 5       Organic Search  20160902
# 6       Organic Search  20160902
# 7       Organic Search  20160902
# 8       Organic Search  20160902
# 9       Organic Search  20160902
# 10      Organic Search  20160902
# 11      Organic Search  20160902
# 12      Organic Search  20160902
# 13      Organic Search  20160902
# 14      Organic Search  20160902
# 15      Organic Search  20160902
# 16      Organic Search  20160902
# 17      Organic Search  20160902
# 18      Organic Search  20160902
# 19      Organic Search  20160902
# 20      Organic Search  20160902
# 21      Organic Search  20160902
# 22      Organic Search  20160902
# 23      Organic Search  20160902
# 24      Organic Search  20160902
# 25      Organic Search  20160902
# 26      Organic Search  20160902
# ...

# %%
lc = df[(df['socialEngagementType'] != 'Socially Engaged')]

# %%
lc.shape
# Out:
# (200000, 12)

# %%
lc = df[(df['socialEngagementType'] == 'Socially Engaged')]

# %%
lc.shape
# Out:
# (0, 12)

# %%
len(df['socialEngagementType'].unique())
# Out:
# 1

# %%
df1 = pd.read_csv("test.csv")
# Out:
# /Users/vivek/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
testdf = pd.read_csv("train.csv", dtype={'fullVisitorId': 'str'})

# %%
testdf = pd.read_csv("test.csv", dtype={'fullVisitorId': 'str'})

# %%
flatten_json <- . %>% 
  str_c(., collapse = ",") %>% 
  str_c("[", ., "]") %>% 
  fromJSON(flatten = T)

parse <- . %>% 
  bind_cols(flatten_json(.$device)) %>%
  bind_cols(flatten_json(.$geoNetwork)) %>% 
  bind_cols(flatten_json(.$trafficSource)) %>% 
  bind_cols(flatten_json(.$totals)) %>% 
  select(-device, -geoNetwork, -trafficSource, -totals)
# Out:
#   File "<ipython-input-34-36853586ac1d>", line 1
#     flatten_json <- . %>%
#                     ^
# SyntaxError: invalid syntax

# %%
library(tidyverse)
library(jsonlite)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-97febefbd70c> in <module>()
# ----> 1 library(tidyverse)
#       2 library(jsonlite)
#
# NameError: name 'library' is not defined

# %%
import jsonlite
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-36-031d04ff05ff> in <module>()
# ----> 1 import jsonlite
#
# ModuleNotFoundError: No module named 'jsonlite'

# %%
library(tidyverse)
library(jsonlite)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-97febefbd70c> in <module>()
# ----> 1 library(tidyverse)
#       2 library(jsonlite)
#
# NameError: name 'library' is not defined

# %%
set.seed(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-8d796f9610a8> in <module>()
# ----> 1 set.seed(0)
#
# AttributeError: type object 'set' has no attribute 'seed'

# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import datetime as datetime
from datetime import timedelta, date
import seaborn as sns
import matplotlib.cm as CM
# %matplotlib inline

# %%
tmp_device_df = pd.DataFrame(train_data.device.apply(json.loads).tolist())[["browser","operatingSystem","deviceCategory","isMobile"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-8839d48a4806> in <module>()
# ----> 1 tmp_device_df = pd.DataFrame(train_data.device.apply(json.loads).tolist())[["browser","operatingSystem","deviceCategory","isMobile"]]
#
# NameError: name 'train_data' is not defined

# %%
tmp_device_df = pd.DataFrame(df.device.apply(json.loads).tolist())[["browser","operatingSystem","deviceCategory","isMobile"]]

# %%
tmp_device_df.describe()
# Out:
#        browser operatingSystem deviceCategory isMobile
# count   804684          804684         804684   804684
# unique     109              22              3        2
# top     Chrome         Windows        desktop    False
# freq    552692          269648         507100   507140

# %%
df["date"] = pd.to_datetime(df["date"],format="%Y%m%d")
df["visitStartTime"] = pd.to_datetime(df["visitStartTime"],unit='s')

# %%
df.head()
# Out:
#   channelGrouping       date  \
# 0  Organic Search 2017-10-16
# 1  Organic Search 2017-10-16
# 2  Organic Search 2017-10-16
# 3  Organic Search 2017-10-16
# 4  Organic Search 2017-10-16
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...  6167871330617112363
# 1  {"browser": "Chrome", "browserVersion": "not a...  0643697640977915618
# 2  {"browser": "Chrome", "browserVersion": "not a...  6059383810968229466
# 3  {"browser": "Safari", "browserVersion": "not a...  2376720078563423631
# 4  {"browser": "Safari", "browserVersion": "not a...  2314544520795440038
#
#                                           geoNetwork  \
# 0  {"continent": "Asia", "subContinent": "Southea...
# 1  {"continent": "Europe", "subContinent": "South...
# 2  {"continent": "Europe", "subContinent": "Weste...
# 3  {"continent": "Americas", "subContinent": "Nor...
# 4  {"continent": "Americas", "subContinent": "Nor...
#
# ...

# %%
#Train dataset
tr_device <- paste("[", paste(df$device, collapse = ","), "]") %>% fromJSON(flatten = T)
tr_geoNetwork <- paste("[", paste(df$geoNetwork, collapse = ","), "]") %>% fromJSON(flatten = T)
tr_totals <- paste("[", paste(df$totals, collapse = ","), "]") %>% fromJSON(flatten = T)
tr_trafficSource <- paste("[", paste(df$trafficSource, collapse = ","), "]") %>% fromJSON(flatten = T)

df <- cbind(df, tr_device, tr_geoNetwork, tr_totals, tr_trafficSource) %>%
  as.data.table()

# drop the old json columns
df[, c('device', 'geoNetwork', 'totals', 'trafficSource') := NULL]
# Out:
#   File "<ipython-input-48-33a4edfccc9b>", line 2
#     tr_device <- paste("[", paste(df$device, collapse = ","), "]") %>% fromJSON(flatten = T)
#                                     ^
# SyntaxError: invalid syntax

# %%
import os
import json
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(200,200)})
sns.set(font_scale=10)

# %%
def load_df(csv_path, nrows=None):
    JSON_COLUMNS = ['device', 'geoNetwork', 'totals', 'trafficSource']
    
    df = pd.read_csv(csv_path, 
                     converters={column: json.loads for column in JSON_COLUMNS}, 
                     dtype={'fullVisitorId': 'str'}, # Important!!
                     nrows=nrows)
    
    for column in JSON_COLUMNS:
        column_as_df = json_normalize(df[column])
        column_as_df.columns = [f"{column}.{subcolumn}" for subcolumn in column_as_df.columns]
        df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
    return df

# %%
df = load_df('train.csv',2_00_000)

# %%
df.head()
# Out:
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20160902  1131660440785968503
# 1  Organic Search  20160902   377306020877927890
# 2  Organic Search  20160902  3895546263509774583
# 3  Organic Search  20160902  4763447161404445595
# 4  Organic Search  20160902    27294437909732085
#
#                         sessionId  socialEngagementType     visitId  \
# 0  1131660440785968503_1472830385  Not Socially Engaged  1472830385
# 1   377306020877927890_1472880147  Not Socially Engaged  1472880147
# 2  3895546263509774583_1472865386  Not Socially Engaged  1472865386
# 3  4763447161404445595_1472881213  Not Socially Engaged  1472881213
# 4    27294437909732085_1472822600  Not Socially Engaged  1472822600
#
#    visitNumber  visitStartTime device.browser             device.browserSize  \
# 0            1      1472830385         Chrome  not available in demo dataset
# 1            1      1472880147        Firefox  not available in demo dataset
# ...

# %%
sapply(df, n_distinct)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-e7721c941cbf> in <module>()
# ----> 1 sapply(df, n_distinct)
#
# NameError: name 'sapply' is not defined

# %%
fea_uniq_values <- sapply(train, n_distinct)
fea_uniq_values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-eac4ea870992> in <module>()
# ----> 1 fea_uniq_values <- sapply(train, n_distinct)
#       2 fea_uniq_values
#
# NameError: name 'fea_uniq_values' is not defined

# %%
fea_uniq_values = sapply(df, n_distinct)
fea_del = names(fea_uniq_values[fea_uniq_values == 1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-fdea9c1910e1> in <module>()
# ----> 1 fea_uniq_values = sapply(df, n_distinct)
#       2 fea_del = names(fea_uniq_values[fea_uniq_values == 1])
#
# NameError: name 'sapply' is not defined

# %%
const_cols = [c for c in df.columns if df[c].nunique(dropna=False)==1 ]
const_cols
# Out:
# ['socialEngagementType',
#  'device.browserSize',
#  'device.browserVersion',
#  'device.flashVersion',
#  'device.language',
#  'device.mobileDeviceBranding',
#  'device.mobileDeviceInfo',
#  'device.mobileDeviceMarketingName',
#  'device.mobileDeviceModel',
#  'device.mobileInputSelector',
#  'device.operatingSystemVersion',
#  'device.screenColors',
#  'device.screenResolution',
#  'geoNetwork.cityId',
#  'geoNetwork.latitude',
#  'geoNetwork.longitude',
#  'geoNetwork.networkLocation',
#  'totals.visits',
#  'trafficSource.adwordsClickInfo.criteriaParameters']

# %%
test = load_df('test.csv',25000)

# %%
cols_to_drop = const_cols + ['sessionId']

df = df.drop(cols_to_drop + ["trafficSource.campaignCode"], axis=1)
test = test.drop(cols_to_drop, axis=1)

# %%
df["date"] = pd.to_datetime(df["date"],format="%Y%m%d")
df["visitStartTime"] = pd.to_datetime(df["visitStartTime"],unit='s')
test["date"] = pd.to_datetime(test["date"],format="%Y%m%d")
test["visitStartTime"] = pd.to_datetime(test["visitStartTime"],unit='s')
